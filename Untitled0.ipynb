# %% [markdown]
# <a href="https://colab.research.google.com/github/SWAROOPSAIKAR/BST/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
categories=['xy','ab','cd','ef','ed','df']
values=['20','30','40','50','60','70']
#plt.bar(categories,values)
plt.plot(categories,values)
plt.xlabel('categories')
plt.ylabel('values')
plt.title('Barchart')
plt.show()
